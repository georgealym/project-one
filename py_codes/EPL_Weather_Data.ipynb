# %%
import pandas as pd
import os
import requests
import json
import matplotlib.pyplot as plt

# %%
weather_df = pd.read_csv("../Resources/england_test_city.csv")
out_path  = "../Resources/EPL_teams"
weather_df.head()
weather_df["Date"] = weather_df["Date"].astype('datetime64[D]')
weather_df["Date"] = weather_df["Date"].dt.strftime("20%y/%d/%m")
weather_df
# Out:
#     Div        Date   Time        HomeTeam          AwayTeam  HomeScore  \
# 0    E0  2019/08/09  20:00       Liverpool           Norwich          4
# 1    E0  2019/08/10  12:30        West Ham          Man City          0
# 2    E0  2019/08/10  15:00     Bournemouth  Sheffield United          1
# 3    E0  2019/08/10  15:00         Burnley       Southampton          3
# 4    E0  2019/08/10  15:00  Crystal Palace           Everton          0
# ..   ..         ...    ...             ...               ...        ...
# 345  E0  2020/07/12  12:00          Wolves           Everton          3
# 346  E0  2020/07/12  14:15     Aston Villa    Crystal Palace          2
# 347  E0  2020/07/12  16:30       Tottenham           Arsenal          2
# 348  E0  2020/07/12  19:00     Bournemouth         Leicester          4
# 349  E0  2020/13/07  20:00      Man United       Southampton          2
#
#      AwayScore Result HomeTeam ID AwayTeam ID           City
# ...

# %%
cities = []
cities = weather_df["City"]
lat = []
lng = []
counter = -1
cities
# Out:
# 0          Liverpool
# 1             London
# 2        Bournemouth
# 3            Burnley
# 4             London
#            ...
# 345    Wolverhampton
# 346       Birmingham
# 347           London
# 348      Bournemouth
# 349       Manchester
# Name: City, Length: 350, dtype: object

# %%
query = "https://maps.googleapis.com/maps/api/geocode/json"
gkey = "AIzaSyAWOynAgsdDOksiFjbs9vlu59bLft4DT2g"
# Exception Handling

for row in cities:
        try:
                params = {"address": row, "key": gkey}
                response = requests.get(query,params=params).json()
                lat.append(response["results"][0]["geometry"]["location"]["lat"])
                lng.append(response["results"][0]["geometry"]["location"]["lng"])
               
                # Increase Processing Record Counter by 1 For Each Loop

        except: 
                print("Oops")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-e0ed90477b0a> in <module>
#      15                 print("Oops")
#      16
# ---> 17 lat.head()
#
# AttributeError: 'list' object has no attribute 'head'

# %%
weather_df["Latitude"] = lat
weather_df["Longidutde"] = lng
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-31e675fb95c4> in <module>
# ----> 1 weather_df["Latitude"] = lat
#       2 weather_df["Longidutde"] = lng
#       3 weather_df
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    2936         else:
#    2937             # set column
# -> 2938             self._set_item(key, value)
#    2939
#    2940     def _setitem_slice(self, key, value):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    2998
#    2999         self._ensure_valid_index(value)
# -> 3000         value = self._sanitize_column(key, value)
#    3001         NDFrame._set_item(self, key, value)
#    3002
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, key, value, broadcast)
#    3634
#    3635             # turn me into an ndarray
# ...

# %%
# 1. What are the geocoordinates (latitude and longitude) of Seattle,
# Washington?
target_city = weather_df["City"][1]
gkey = "AIzaSyAWOynAgsdDOksiFjbs9vlu59bLft4DT2g"
params = {"address": target_city, "key": gkey}

# Build URL using the Google Maps API


print(f"Drill #1: The Geocoordinates of {target_city}")

# Run request
response = requests.get(base_url, params=params)

# print the response URL, avoid doing for public GitHub repos in order to avoid exposing key
# print(response.url)

# Convert to JSON
geo = response.json()

# Extract lat/lng
lat = geo["results"][0]["geometry"]["location"]["lat"]
lng = geo["results"][0]["geometry"]["location"]["lng"]

# Print results
print(f"{target_city}: {lat}, {lng}")

# %%
#key = "fSCUTLIVa943ddLYaP6ZKkDBwTXmgYxt"
#base_url = "https://api.meteostat.net/v2/point/daily?lat=33.749&lon=-84.388&alt=336&start=2019-06-01&end=2019-06-30:i&key="
#url = base_url + key
#print(url)
#response = requests.get(url)
#print(response)
## Storing the JSON response within a variable
#data = response.json()
## Use json.dumps to print the json
#print(json.dumps(data, indent=4, sort_keys=True))

# %%
#key = "fSCUTLIVa943ddLYaP6ZKkDBwTXmgYxt"
#https://api.meteostat.net/v1/history/hourly?
#    station=03772&start=2019-05-02&end=2019-05-11&time_zone=Europe/London&time_format=Y-m-d%20H:i&key=[YOUR KEY HERE]
