# %%
import pandas as pd
import os
import requests
import json
import matplotlib.pyplot as plt

# %%
weather_df = pd.read_csv("../Resources/reduced_england.csv")
out_path  = "../Resources/EPL_teams"
weather_df.head()
#weather_df["Date"] = weather_df["Date"].astype('datetime64[D]')
#weather_df["Date"] = weather_df["Date"].dt.strftime("20%y/%d/%m")
weather_df
# Out:
#    Div        Date   Time        HomeTeam          AwayTeam  HomeScore  \
# 0   E0  2019-09-08  20:00       Liverpool           Norwich          4
# 1   E0  2019-10-08  12:30        West Ham          Man City          0
# 2   E0  2019-10-08  15:00     Bournemouth  Sheffield United          1
# 3   E0  2019-10-08  15:00         Burnley       Southampton          3
# 4   E0  2019-10-08  15:00  Crystal Palace           Everton          0
# 5   E0  2019-10-08  15:00         Watford          Brighton          0
# 6   E0  2019-10-08  17:30       Tottenham       Aston Villa          3
# 7   E0  2019-11-08  14:00       Leicester            Wolves          0
# 8   E0  2019-11-08  14:00       Newcastle           Arsenal          0
# 9   E0  2019-11-08  16:30      Man United           Chelsea          4
# 10  E0  2019-17-08  12:30         Arsenal           Burnley          2
#
#     AwayScore Result HomeTeam ID AwayTeam ID                 City
# ...

# %%
cities = []
cities = weather_df["City"]
lat = []
lng = []

# %%
query = "https://maps.googleapis.com/maps/api/geocode/json"
gkey = "AIzaSyAWOynAgsdDOksiFjbs9vlu59bLft4DT2g"
# Exception Handling

for row in cities:
        try:
                params = {"address": row, "key": gkey}
                response = requests.get(query,params=params).json()
                lat.append(response["results"][0]["geometry"]["location"]["lat"])
                lng.append(response["results"][0]["geometry"]["location"]["lng"])
               
                # Increase Processing Record Counter by 1 For Each Loop

        except: 
                print("Oops")

# %%
print(lng)

# %%
weather_df["Latitude"] = lat
weather_df["Longitude"] = lng 
weather_df
# Out:
#    Div        Date   Time        HomeTeam          AwayTeam  HomeScore  \
# 0   E0  2019-09-08  20:00       Liverpool           Norwich          4
# 1   E0  2019-10-08  12:30        West Ham          Man City          0
# 2   E0  2019-10-08  15:00     Bournemouth  Sheffield United          1
# 3   E0  2019-10-08  15:00         Burnley       Southampton          3
# 4   E0  2019-10-08  15:00  Crystal Palace           Everton          0
# 5   E0  2019-10-08  15:00         Watford          Brighton          0
# 6   E0  2019-10-08  17:30       Tottenham       Aston Villa          3
# 7   E0  2019-11-08  14:00       Leicester            Wolves          0
# 8   E0  2019-11-08  14:00       Newcastle           Arsenal          0
# 9   E0  2019-11-08  16:30      Man United           Chelsea          4
# 10  E0  2019-17-08  12:30         Arsenal           Burnley          2
#
#     AwayScore Result HomeTeam ID AwayTeam ID                 City   Latitude  \
# ...

# %%
cities = weather_df["City"]
lat = weather_df["Latitude"]
lng = weather_df["Longitude"]
date = weather_df["Date"]
formatver = "json"
q = str(latitude1) + "," + str(longitude1)
averagetemp = []

# %%
url = "http://api.worldweatheronline.com/premium/v1/past-weather.ashx"
key = "65124be1e28144ea98100632201807"

for index,row in weather_df.iterrows():
    lat = row["Latitude"]
    lng = row["Longitude"]
    date = row["Date"]
    q = str(lat) + "," + str(lng)
    try:
                params = {"q": q,"format": formatver,"key" : key,"date": start}
                response = requests.get(url,params=params).json()
                averagetemp.append(response["data"]["weather"][0]["avgtempF"])
                # Increase Processing Record Counter by 1 For Each Loop

    except: 
                print("Oops")

# %%
print(averagetemp)
# Out:
# ['96', '61', '57', '79', '61', '55', '61', '56', '58', '59', '61']

# %%
#weather_key = "65124be1e28144ea98100632201807"
#from wwo_hist import retrieve_hist_data
 #   frequency = 3
  #  start_date = '09-AUG-2019'
   # end_date = '17-JUL-2020'
    #api_key = weather_key
    #location_list = [cities]
   # hist_weather_data = retrieve_hist_data(api_key,
    #                                location_list,
     #                               start_date,
      #                              end_date,
       #                             frequency,
        #                            location_label = False,
         #                           export_csv = True,
          #                          store_df = True)

# %%
#url="http://api.worldweatheronline.com/premium/v1/weather.ashx?key=xxxxxxxxxxxxx&q=48.85,2.35&num_of_days=2&tp=3&format=xml"
import requests
import json
url = "http://api.worldweatheronline.com/premium/v1/past-weather.ashx"
key = "65124be1e28144ea98100632201807"
latitude1 = weather_df["Latitude"][0]
longitude1 = weather_df["Longitude"][0]
city1 = weather_df["City"][0]
start = weather_df["Date"][0]
end = weather_df["Date"][0]
time= weather_df["Time"][0]
tp = 3
formatver = "json"
q = str(latitude1) + "," + str(longitude1)
print(q)
# Out:
# 32.6564981,-115.4763241

# %%
#https://api.worldweatheronline.com/premium/v1/past-weather.ashx?q=new+york&tp=24&format=json&key=ourApiKey&date=2008-12-25
params = {
    "q": q,
    #"tp":tp,
    "format": formatver,
    "key" : key,
    "date": start
}

# base url

# run a request using our params dictionary
response = requests.get(url, params=params)
tempdata = response.json()
print(json.dumps(tempdata, indent=4, sort_keys=True))
# Out:
# {
#     "data": {
#         "request": [
#             {
#                 "query": "Lat 32.66 and Lon -115.48",
#                 "type": "LatLon"
#             }
#         ],
#         "weather": [
#             {
#                 "astronomy": [
#                     {
#                         "moon_illumination": "62",
#                         "moon_phase": "First Quarter",
#                         "moonrise": "03:54 PM",
#                         "moonset": "01:20 AM",
#                         "sunrise": "06:21 AM",
#                         "sunset": "06:58 PM"
#                     }
#                 ],
#                 "avgtempC": "36",
#                 "avgtempF": "96",
#                 "date": "2019-09-08",
#                 "hourly": [
#                     {
#                         "DewPointC": "5",
#                         "DewPointF": "40",
#                         "FeelsLikeC": "34",
#                         "FeelsLikeF": "94",
# ...

# %%
print(tempdata["data"]["weather"][0]["avgtempF"])
# Out:
# 96

# %%
requesturl = url + key
response = requests.get(requesturl)
print(url)

# %%
#key = "fSCUTLIVa943ddLYaP6ZKkDBwTXmgYxt"
#base_url = "https://api.meteostat.net/v2/point/daily?lat=33.749&lon=-84.388&alt=336&start=2019-06-01&end=2019-06-30:i&key="
#url = base_url + key
#print(url)
#response = requests.get(url)
#print(response)
## Storing the JSON response within a variable
#data = response.json()
## Use json.dumps to print the json
#print(json.dumps(data, indent=4, sort_keys=True))

# %%
#key = "fSCUTLIVa943ddLYaP6ZKkDBwTXmgYxt"
#https://api.meteostat.net/v1/history/hourly?
#    station=03772&start=2019-05-02&end=2019-05-11&time_zone=Europe/London&time_format=Y-m-d%20H:i&key=[YOUR KEY HERE]
