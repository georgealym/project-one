# %%
import pandas as pd
import os
import requests
import json
import matplotlib.pyplot as plt

# %%
EPL_df = pd.read_csv("../final-resources/EPL_scores_att_weather.csv")
Bundesliga_df = pd.read_csv("../final-resources/Bundesliga_scores_weather.csv")
LaLiga_df =  pd.read_csv("../final-resources/la_liga_scores_weather.csv")
SerieA_df = pd.read_csv("../final-resources/Serie_A_weather.csv")

# %%
vertical_stack = pd.concat([EPL_df,Bundesliga_df,LaLiga_df,SerieA_df], axis=0)
vertical_stack
# Out:
#      Unnamed: 0 Div        Date   Time        HomeTeam     AwayTeam  \
# 0             0  E0  2019-08-09  20:00       Liverpool      Norwich
# 1             1  E0  2019-08-10  12:30        West Ham     Man City
# 2             2  E0  2019-08-10  15:00         Watford     Brighton
# 3             3  E0  2019-08-10  17:30       Tottenham  Aston Villa
# 4             4  E0  2019-08-10  15:00  Crystal Palace      Everton
# ..          ...  ..         ...    ...             ...          ...
# 315         315  I1  2020-07-12  18:30      Fiorentina       Verona
# 316         316  I1  2020-07-12  18:30           Parma      Bologna
# 317         317  I1  2020-07-12  18:30         Udinese    Sampdoria
# 318         318  I1  2020-07-12  20:45          Napoli        Milan
# 319         319  I1  2020-07-13  20:45           Inter       Torino
#
#      HomeScore  AwayScore Result HomeTeam ID AwayTeam ID       City Team ID  \
# 0            4          1      H        EPL9       EPL13  Liverpool    EPL9
# 1            0          5      A       EPL18       EPL10     London   EPL18
# 2            0          3      A       EPL17        EPL3    Watford   EPL17
# 3            3          1      H       EPL16        EPL1     London   EPL16
# 4            0          0      D        EPL6        EPL7     London    EPL6
# ..         ...        ...    ...         ...         ...        ...     ...
# 315          1          1      D        SER4       SER19        NaN     NaN
# 316          2          2      D       SER12        SER1        NaN     NaN
# 317          1          3      A       SER18       SER14        NaN     NaN
# 318          2          2      D       SER11       SER10        NaN     NaN
# 319          3          1      H        SER6       SER17        NaN     NaN
#
#                    Opponent  Attendance   Latitude  Longitude  \
# 0              Norwich City     53333.0  53.408371  -2.991573
# 1           Manchester City     59870.0  51.507351  -0.127758
# 2    Brighton & Hove Albion     20245.0  51.656489  -0.390320
# 3               Aston Villa     60407.0  51.507351  -0.127758
# 4                   Everton     25151.0  51.507351  -0.127758
# ..                      ...         ...        ...        ...
# 315                     NaN         NaN  43.769560  11.255814
# 316                     NaN         NaN  44.801485  10.327904
# 317                     NaN         NaN  46.071067  13.234579
# 318                     NaN         NaN  40.851798  14.268120
# 319                     NaN         NaN  45.464203   9.189982
#
#      Avg Temp (in F)      City  Unnamed: 11
# 0                 69       NaN          NaN
# 1                 68       NaN          NaN
# 2                 64       NaN          NaN
# 3                 68       NaN          NaN
# 4                 68       NaN          NaN
# ..               ...       ...          ...
# 315               80  Florence          NaN
# 316               75     Parma          NaN
# 317               72     Udine          NaN
# 318               86    Naples          NaN
# 319               74     Milan          NaN
#
# [1337 rows x 20 columns]

# %%
vertical_stack
all_weather = vertical_stack[["Div","Date","HomeScore","AwayScore","Result","Avg Temp (in F)"]]
all_weather
all_weather.to_csv("../final-resources/All_Weather_Data.csv")
#colors = all_weather["Result"].replace(["H","A","D"], ["r","b","g"])
# Scatter plot
#xval = all_weather["Avg Temp (in F)"]
#yval = [all_weather["HomeScore"]]
#fig,(ax1,ax2)= plt.subplots(2)
#plt.scatter(xval, yval[0], c=colors,label="Home")
#plt.figure(figsize = (8,8))

#ax1.set_title("Weather vs. Score")
#ax.legend()
#plt.show()
#plt.savefig("Fig1.png")

# %%
#fig,(ax1,ax2)= plt.subplots(2)
#ax2.scatter(xval, yval[1], c=colors,label="Away")
#ax2.set_xlabel("Avg Temp (in F)")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-5-7144cfbd3daf> in <module>
#       1 fig,(ax1,ax2)= plt.subplots(2)
# ----> 2 ax2.scatter(xval, yval[1], c=colors,label="Away")
#       3 ax2.set_xlabel("Avg Temp (in F)")
#
# IndexError: list index out of range
