# %%
import pandas as pd
import os
import requests
import json
import matplotlib.pyplot as plt
import numpy as np

# %%
EPL_df = pd.read_csv("../final-resources/EPL_scores_att_weather.csv")
Bundesliga_df = pd.read_csv("../final-resources/Bundesliga_scores_weather.csv")
LaLiga_df =  pd.read_csv("../final-resources/la_liga_scores_weather.csv")
SerieA_df = pd.read_csv("../final-resources/Serie_A_weather.csv")

# %%
EPL_df.head()
# Create bins in which to place values based upon TED Talk views
bins = [0, 39, 49, 59, 69, 79, 89]

# Create labels for these bins
group_labels = ["0 to 40", "40 to 50", "50 to 60", "60 to 70", "70 to 80", "80 to 90"]

#put data in bins
EPL_df["Temperature Group"]=pd.cut(EPL_df["Avg Temp (in F)"], bins, labels=group_labels)
# Create a GroupBy object based upon "View Group"
EPL_dfgroup = EPL_df.groupby("Temperature Group")
home = EPL_dfgroup["HomeScore"].mean()
away = EPL_dfgroup["AwayScore"].mean()
fig,ax = plt.subplots(figsize=(10,5))
n = len(home)
x = np.arange(n)
w = 0.4
ax.set_title(f"EPL Comparison of Average Number of Goals in Temperature Ranges (F) ", fontsize=20)
ax.bar(x-w/2, home, color ="crimson", edgecolor ="gray", label ="Home Score", width = w)
ax.bar(x+w/2, away, color ="midnightblue", edgecolor ="gray", label ="Away Score", width = w)
#  ax.set_xlim(-0.5, n-0.5)
ax.set_xticks(x)
ax.set_xticklabels(group_labels)
ax.set_ylabel("Number of wins", fontsize=10)
ax.set_xlabel("Temperature Ranges in F", fontsize = 10)
ax.legend()
fig.savefig(f"EPL_weather_bins.png", bbox_inches='tight')
plt.show()
plt.close(fig)

# %%
Bundesliga_df.head()
# Create bins in which to place values based upon TED Talk views
bins = [0, 39, 49, 59, 69, 79, 89]

# Create labels for these bins
group_labels = ["0 to 40", "40 to 50", "50 to 60", "60 to 70", "70 to 80", "80 to 90"]

#put data in bins
Bundesliga_df["Temperature Group"]=pd.cut(Bundesliga_df["Avg Temp (in F)"], bins, labels=group_labels)
# Create a GroupBy object based upon "View Group"
Bundesliga_dfgroup = Bundesliga_df.groupby("Temperature Group")
home = Bundesliga_dfgroup["HomeScore"].mean()
away = Bundesliga_dfgroup["AwayScore"].mean()
fig,ax = plt.subplots(figsize=(10,5))
n = len(home)
x = np.arange(n)
w = 0.4
ax.set_title(f"BUN Comparison of Average Number of Goals in Temperature Ranges (F) ", fontsize=20)
ax.bar(x-w/2, home, color ="red", edgecolor ="gray", label ="Home Score", width = w)
ax.bar(x+w/2, away, color ="goldenrod", edgecolor ="gray", label ="Away Score", width = w)
#  ax.set_xlim(-0.5, n-0.5)
ax.set_xticks(x)
ax.set_xticklabels(group_labels)
ax.set_ylabel("Number of wins", fontsize=10)
ax.set_xlabel("Temperature Ranges in F", fontsize = 10)
ax.legend()
fig.savefig(f"BUN_weather_bins.png", bbox_inches='tight')
plt.show()
plt.close(fig)

# %%
LaLiga_df.head()
# Create bins in which to place values based upon TED Talk views
bins = [0, 39, 49, 59, 69, 79, 89,120]

# Create labels for these bins
group_labels = ["0 to 40", "40 to 50", "50 to 60", "60 to 70", "70 to 80", "80 to 90","above 90"]

#put data in bins
LaLiga_df["Temperature Group"]=pd.cut(LaLiga_df["Avg Temp (in F)"], bins, labels=group_labels)
# Create a GroupBy object based upon "View Group"
LaLiga_dfgroup = LaLiga_df.groupby("Temperature Group")
home = LaLiga_dfgroup["HomeScore"].mean()
away = LaLiga_dfgroup["AwayScore"].mean()
fig,ax = plt.subplots(figsize=(10,5))
n = len(home)
x = np.arange(n)
w = 0.4
ax.set_title(f"LIG Comparison of Average Number of Goals in Temperature Ranges (F) ", fontsize=20)
ax.bar(x-w/2, home, color ="orangered", edgecolor ="gray", label ="Home Score", width = w)
ax.bar(x+w/2, away, color ="limegreen", edgecolor ="gray", label ="Away Score", width = w)
#  ax.set_xlim(-0.5, n-0.5)
ax.set_xticks(x)
ax.set_xticklabels(group_labels)
ax.set_ylabel("Number of wins", fontsize=10)
ax.set_xlabel("Temperature Ranges in F", fontsize = 10)
ax.legend()
fig.savefig(f"LIG_weather_bins.png", bbox_inches='tight')
plt.show()
plt.close(fig)

# %%
SerieA_df.head()
# Create bins in which to place values based upon TED Talk views
bins = [0, 49, 59, 69, 79, 89]

# Create labels for these bins
group_labels = ["40 to 50", "50 to 60", "60 to 70", "70 to 80", "80 to 90"]

#put data in bins
SerieA_df["Temperature Group"]=pd.cut(SerieA_df["Avg Temp (in F)"], bins, labels=group_labels)
# Create a GroupBy object based upon "View Group"
SerieA_dfgroup = SerieA_df.groupby("Temperature Group")
home = SerieA_dfgroup["HomeScore"].mean()
away = SerieA_dfgroup["AwayScore"].mean()
fig,ax = plt.subplots(figsize=(10,5))
n = len(home)
x = np.arange(n)
w = 0.4
ax.set_title(f"SER Comparison of Average Number of Goals in Temperature Ranges (F) ", fontsize=20)
ax.bar(x-w/2, home, color ="mediumblue", edgecolor ="gray", label ="Home Score", width = w)
ax.bar(x+w/2, away, color ="deepskyblue", edgecolor ="gray", label ="Away Score", width = w)
#  ax.set_xlim(-0.5, n-0.5)
ax.set_xticks(x)
ax.set_xticklabels(group_labels)
ax.set_ylabel("Number of wins", fontsize=10)
ax.set_xlabel("Temperature Ranges in F", fontsize = 10)
ax.legend()
fig.savefig(f"SER_weather_bins.png", bbox_inches='tight')
plt.show()
plt.close(fig)

# %%
vertical_stack = pd.concat([EPL_df,Bundesliga_df,LaLiga_df,SerieA_df], axis=0)
vertical_stack
# Out:
#      Unnamed: 0 Div        Date   Time        HomeTeam     AwayTeam  \
# 0             0  E0  2019-08-09  20:00       Liverpool      Norwich
# 1             1  E0  2019-08-10  12:30        West Ham     Man City
# 2             2  E0  2019-08-10  15:00         Watford     Brighton
# 3             3  E0  2019-08-10  17:30       Tottenham  Aston Villa
# 4             4  E0  2019-08-10  15:00  Crystal Palace      Everton
# ..          ...  ..         ...    ...             ...          ...
# 315         315  I1  2020-07-12  18:30      Fiorentina       Verona
# 316         316  I1  2020-07-12  18:30           Parma      Bologna
# 317         317  I1  2020-07-12  18:30         Udinese    Sampdoria
# 318         318  I1  2020-07-12  20:45          Napoli        Milan
# 319         319  I1  2020-07-13  20:45           Inter       Torino
#
#      HomeScore  AwayScore Result HomeTeam ID  ...       City Team ID  \
# 0            4          1      H        EPL9  ...  Liverpool    EPL9
# 1            0          5      A       EPL18  ...     London   EPL18
# 2            0          3      A       EPL17  ...    Watford   EPL17
# 3            3          1      H       EPL16  ...     London   EPL16
# 4            0          0      D        EPL6  ...     London    EPL6
# ..         ...        ...    ...         ...  ...        ...     ...
# 315          1          1      D        SER4  ...        NaN     NaN
# 316          2          2      D       SER12  ...        NaN     NaN
# 317          1          3      A       SER18  ...        NaN     NaN
# 318          2          2      D       SER11  ...        NaN     NaN
# 319          3          1      H        SER6  ...        NaN     NaN
#
#                    Opponent Attendance   Latitude  Longitude  Avg Temp (in F)  \
# 0              Norwich City    53333.0  53.408371  -2.991573               69
# 1           Manchester City    59870.0  51.507351  -0.127758               68
# 2    Brighton & Hove Albion    20245.0  51.656489  -0.390320               64
# 3               Aston Villa    60407.0  51.507351  -0.127758               68
# 4                   Everton    25151.0  51.507351  -0.127758               68
# ..                      ...        ...        ...        ...              ...
# 315                     NaN        NaN  43.769560  11.255814               80
# 316                     NaN        NaN  44.801485  10.327904               75
# 317                     NaN        NaN  46.071067  13.234579               72
# 318                     NaN        NaN  40.851798  14.268120               86
# 319                     NaN        NaN  45.464203   9.189982               74
#
#      Temperature Group      City Unnamed: 11
# 0             60 to 70       NaN         NaN
# 1             60 to 70       NaN         NaN
# 2             60 to 70       NaN         NaN
# 3             60 to 70       NaN         NaN
# 4             60 to 70       NaN         NaN
# ..                 ...       ...         ...
# 315           80 to 90  Florence         NaN
# 316           70 to 80     Parma         NaN
# 317           70 to 80     Udine         NaN
# 318           80 to 90    Naples         NaN
# 319           70 to 80     Milan         NaN
#
# [1337 rows x 21 columns]

# %%
vertical_stack
all_weather = vertical_stack[["Div","Date","HomeScore","AwayScore","Result","Avg Temp (in F)"]]
all_weather
#all_weather.to_csv("../final-resources/All_Weather_Data.csv")
colors = all_weather["Result"].replace(["H","A","D"], ["b","b","b"])
#Scatter plot
xval = [all_weather["Avg Temp (in F)"]]
yval = [all_weather["HomeScore"]]

plt.scatter(xval, yval[0], c=colors,label="Home")
plt.figure(figsize = (8,8))

#ax1.set_title("Weather vs. Score")
#ax.legend()
#plt.show()
#plt.savefig("Fig1.png")
colors = all_weather["Result"].replace(["H","A","D"], ["g","g","g"])
#Scatter plot
xval = all_weather["Avg Temp (in F)"]
yval = [all_weather["AwayScore"]]

plt.scatter(xval, yval[0], c=colors,label="Home")
plt.figure(figsize = (8,8))
#create bins for temperatures and look at score data and then find the average score per temp for home vs away 
#group.by temperature.mean ()
#bar chart in bins

# %%
# Create bins in which to place values based upon TED Talk views
bins = [0, 39, 49, 59, 69, 79, 89,120]

# Create labels for these bins
group_labels = ["0 to 40", "40 to 50", "50 to 60", "60 to 70", "70 to 80", "80 to 90","above 90"]

#put data in bins
all_weather["Temperature Group"]=pd.cut(all_weather["Avg Temp (in F)"], bins, labels=group_labels)

# Create a GroupBy object based upon "View Group"
all_weathergroup = all_weather.groupby("Temperature Group")

# Find how many rows fall into each bin
print(all_weathergroup["Result"].count())
results= all_weathergroup["Result"].value_counts()
print(results)
# Get the average of each column within the GroupBy object
average = all_weathergroup.mean()
print(average)
# Out:
# Temperature Group
# 0 to 40      43
# 40 to 50    354
# 50 to 60    324
# 60 to 70    283
# 70 to 80    189
# 80 to 90    140
# above 90      4
# Name: Result, dtype: int64
# Temperature Group  Result
# 0 to 40            H          20
#                    A          13
#                    D          10
# 40 to 50           H         148
#                    A         116
#                    D          90
# 50 to 60           H         149
#                    A         103
#                    D          72
# 60 to 70           H         118
#                    A          86
#                    D          79
# 70 to 80           H          83
#                    A          65
#                    D          41
# 80 to 90           H          56
#                    A          49
#                    D          35
# above 90           H           3
#                    A           1
# Name: Result, dtype: int64
#                    HomeScore  AwayScore  Avg Temp (in F)
# Temperature Group
# 0 to 40             1.720930   1.395349        37.604651
# 40 to 50            1.522599   1.262712        45.087571
# 50 to 60            1.595679   1.299383        54.527778
# 60 to 70            1.579505   1.279152        64.053004
# 70 to 80            1.465608   1.222222        74.195767
# 80 to 90            1.471429   1.400000        82.850000
# above 90            1.500000   0.250000        92.250000
# C:\Users\george.a.4\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
home = all_weathergroup["HomeScore"].mean()
away = all_weathergroup["AwayScore"].mean()
fig,ax = plt.subplots(figsize=(10,5))
n = len(home)
x = np.arange(n)
w = 0.4
ax.set_title(f"Comparison of Average Number of Goals All Leagues in Temperature Ranges (F) ", fontsize=20)
ax.bar(x-w/2, home, color ="darkslateblue", edgecolor ="gray", label ="Home Score", width = w)
ax.bar(x+w/2, away, color ="palegoldenrod", edgecolor ="gray", label ="Away Score", width = w)
#  ax.set_xlim(-0.5, n-0.5)
ax.set_xticks(x)
ax.set_xticklabels(group_labels)
ax.set_ylabel("Number of wins", fontsize=10)
ax.set_xlabel("Temperature Ranges in F", fontsize = 10)
ax.legend()
#fig.savefig(f"{images_path}{league}_bar_scores_att_bins.png", bbox_inches='tight')
plt.show()
plt.close(fig)

# %%
results= all_weathergroup["Result"].value_counts()
results
# Out:
# Temperature Group  Result
# 0 to 40            H          20
#                    A          13
#                    D          10
# 40 to 50           H         148
#                    A         116
#                    D          90
# 50 to 60           H         149
#                    A         103
#                    D          72
# 60 to 70           H         118
#                    A          86
#                    D          79
# 70 to 80           H          83
#                    A          65
#                    D          41
# 80 to 90           H          56
#                    A          49
#                    D          35
# above 90           H           3
#                    A           1
# Name: Result, dtype: int64
