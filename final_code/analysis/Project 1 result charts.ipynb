# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import pie, axis, show
import os
import numpy as np

# %%
# England
England_pre_df = pd.read_csv("england_pre.csv")
England_pre_df

England_post_df = pd.read_csv("england_post.csv")
England_post_df
# Out:
#    Div        Date   Time     HomeTeam          AwayTeam  HomeScore  \
# 0   E0  17/06/2020  18:00  Aston Villa  Sheffield United          0
# 1   E0  17/06/2020  20:15     Man City           Arsenal          3
# 2   E0  19/06/2020  18:00      Norwich       Southampton          0
# 3   E0  19/06/2020  20:15    Tottenham        Man United          1
# 4   E0  20/06/2020  12:30      Watford         Leicester          1
# ..  ..         ...    ...          ...               ...        ...
# 57  E0     12/7/20  12:00       Wolves           Everton          3
# 58  E0     12/7/20  14:15  Aston Villa    Crystal Palace          2
# 59  E0     12/7/20  16:30    Tottenham           Arsenal          2
# 60  E0     12/7/20  19:00  Bournemouth         Leicester          4
# 61  E0  13/07/2020  20:00   Man United       Southampton          2
#
#     AwayScore Result HomeTeam ID AwayTeam ID           City
# 0           0      D        EPL1       EPL14     Birmingham
# ...

# %%
count1 = England_pre_df["Result"].value_counts()
count1
count2 = England_post_df["Result"].value_counts()
count2
# Out:
# H    30
# A    19
# D    13
# Name: Result, dtype: int64

# %%
result_type = ["Home Wins", "Away Wins", "Draws"]
results = [129,87,72]
colors = ["crimson","mistyrose","silver"]
explode = (0.1,0,0)

result2_type = ["Home Wins", "Away Wins", "Draws"]
results2 = [30,19,13]
colors2 = ["crimson","mistyrose","silver"]
explode2 = (0.1,0,0)

# %%
EPL1 = plt.figure(1)
plt.pie(results, explode=explode, colors=colors, 
        autopct="%1.1f%%", shadow=True, startangle=90)
legend_labels = [r"Home Wins (129)", r"Away Wins (87)", r"Draws (72)"]
plt.axis("equal")
plt.title("English Premier League home/away results with fans")
plt.legend(legend_labels, loc="lower left")

EPL2 = plt.figure(2)
plt.pie(results2, explode=explode2, colors=colors2, 
        autopct="%1.1f%%", shadow=True, startangle=90)
legend_labels = [r"Home Wins (30)", r"Away Wins (19)", r"Draws (13)"]
plt.axis("equal")
plt.title("English Premier League home/away results without fans")
plt.legend(legend_labels, loc="lower left")

plt.savefig("EPL1.png")
plt.savefig("EPL2.png")
plt.show()

# %%
# Germany
Germany_pre_df = pd.read_csv("germany_pre.csv")

Germany_post_df = pd.read_csv("germany_post.csv")
Germany_post_df.head()
# Out:
#   Div        Date   Time            HomeTeam    AwayTeam  HomeScore  \
# 0  D1  16/05/2020  14:30            Augsburg   Wolfsburg          1
# 1  D1  16/05/2020  14:30            Dortmund  Schalke 04          4
# 2  D1  16/05/2020  14:30  Fortuna Dusseldorf   Paderborn          0
# 3  D1  16/05/2020  14:30          Hoffenheim      Hertha          0
# 4  D1  16/05/2020  14:30          RB Leipzig    Freiburg          1
#
#    AwayScore Result HomeTeam ID AwayTeam ID        City
# 0          2      A        BUN0       BUN17    Augsburg
# 1          0      H        BUN2       BUN14    Dortmund
# 2          0      D        BUN5       BUN12  Dusseldorf
# 3          3      A        BUN8        BUN7    Sinsheim
# 4          1      D       BUN13        BUN6     Leipzig

# %%
count3 = Germany_pre_df["Result"].value_counts()
count4 = Germany_post_df["Result"].value_counts()
count4
# Out:
# A    37
# H    26
# D    19
# Name: Result, dtype: int64

# %%
result3_type = ["Home Wins", "Away Wins", "Draws"]
results3 = [97,78,49]
colors3 = ["red","gold","silver"]
explode3 = (0.1,0,0)

result4_type = ["Home Wins", "Away Wins", "Draws"]
results4 = [37,26,19]
colors4 = ["red","gold","silver"]
explode4 = (0.1,0,0)

# %%
BUN1 = plt.figure(3)
plt.pie(results3, explode=explode3, colors=colors3, 
        autopct="%1.1f%%", shadow=True, startangle=90)
legend_labels = [r"Home Wins (97)", r"Away Wins (78)", r"Draws (49)"]
plt.axis("equal")
plt.title("German Bundesliga home/away results with fans")
plt.legend(legend_labels, loc="lower left")


BUN2 = plt.figure(4)
plt.pie(results4, explode=explode4, colors=colors4, 
        autopct="%1.1f%%", shadow=True, startangle=90)
legend_labels = [r"Home Wins (37)", r"Away Wins (26)", r"Draws (19)"]
plt.axis("equal")
plt.title("German Bundesliga home/away results without fans")
plt.legend(legend_labels, loc="lower left")

plt.savefig("BUN1.png")
plt.savefig("BUN2.png")
plt.show()

# %%
# Italy
Italy_pre_df = pd.read_csv("Italy_pre.csv")
Italy_post_df = pd.read_csv("Italy_post.csv")
Italy_post_df.head()
# Out:
#   Div        Date   Time    HomeTeam   AwayTeam  HomeScore  AwayScore Result  \
# 0  I1  20/06/2020  18:30      Torino      Parma          1          1      D
# 1  I1  20/06/2020  20:45      Verona   Cagliari          2          1      H
# 2  I1  21/06/2020  18:30    Atalanta   Sassuolo          4          1      H
# 3  I1  21/06/2020  20:45       Inter  Sampdoria          2          1      H
# 4  I1  22/06/2020  18:30  Fiorentina    Brescia          1          1      D
#
#   HomeTeam ID AwayTeam ID      City
# 0       SER17       SER12     Turin
# 1       SER19        SER3    Verona
# 2        SER0       SER15   Bergamo
# 3        SER6       SER14     Milan
# 4        SER4        SER2  Florence

# %%
count5 = Italy_pre_df["Result"].value_counts()
count6 = Italy_post_df["Result"].value_counts()
count6
# Out:
# H    26
# A    23
# D    15
# Name: Result, dtype: int64

# %%
results5_type = ["Home Wins", "Away Wins", "Draws"]
results5 = [103,95,58]
colors5 = ["royalblue","powderblue","silver"]
explode5 = (0.1,0,0)

results6_type = ["Home Wins", "Away Wins", "Draws"]
results6 = [26,23,15]
colors6 = ["royalblue","powderblue","silver"]
explode6 = (0.1,0,0)

# %%
SER1 = plt.figure(5)
plt.pie(results5, explode=explode5, colors=colors5, 
        autopct="%1.1f%%", shadow=True, startangle=90)
legend_labels = [r"Home Wins (103)", r"Away Wins (95)", r"Draws (58)"]
plt.axis("equal")
plt.title("Italian Serie A home/away results with fans")
plt.legend(legend_labels, loc="lower left")

SER2 = plt.figure(6)
plt.pie(results6, explode=explode6, colors=colors6, 
        autopct="%1.1f%%", shadow=True, startangle=90)
legend_labels = [r"Home Wins (26)", r"Away Wins (23)", r"Draws (15)"]
plt.axis("equal")
plt.title("Italian Serie A home/away results without fans")
plt.legend(legend_labels, loc="lower left")

plt.savefig("SER1.png")
plt.savefig("SER2.png")
plt.show()

# %%
# Spain
Spain_pre_df = pd.read_csv("spain_pre.csv")
Spain_post_df = pd.read_csv("spain_post.csv")
Spain_post_df.head()
# Out:
#    Div        Date   Time  HomeTeam    AwayTeam  HomeScore  AwayScore Result  \
# 0  SP1     11/6/20  21:00   Sevilla       Betis          2          0      H
# 1  SP1     12/6/20  18:30   Granada      Getafe          2          1      H
# 2  SP1     12/6/20  21:00  Valencia     Levante          1          1      D
# 3  SP1  13/06/2020  13:00   Espanol      Alaves          2          0      H
# 4  SP1  13/06/2020  16:00     Celta  Villarreal          0          1      A
#
#   HomeTeam ID AwayTeam ID       City
# 0       LIG15        LIG4    Seville
# 1        LIG9        LIG8    Granada
# 2       LIG17       LIG11   Valencia
# 3        LIG7        LIG0  Barcelona
# 4        LIG5       LIG19       Vigo

# %%
count7 = Spain_pre_df["Result"].value_counts()
count8 = Spain_post_df["Result"].value_counts()
count8
# Out:
# H    37
# A    28
# D    25
# Name: Result, dtype: int64

# %%
results7_type = ["Home Wins", "Away Wins", "Draws"]
results7 = [129,75,66]
colors7 = ["orangered","bisque","silver"]
explode7 = (0.1,0,0)

results8_type = ["Home Wins", "Away Wins", "Draws"]
results8 = [37,28,25]
colors8 = ["orangered","bisque","silver"]
explode8 = (0.1,0,0)

# %%
LIG1 = plt.figure(7)
plt.pie(results7, explode=explode7, colors=colors7, 
        autopct="%1.1f%%", shadow=True, startangle=90)
legend_labels = [r"Home Wins (129)", r"Away Wins (75)", r"Draws (66)"]
plt.axis("equal")
plt.title("Spanish La Liga home/away results with fans")
plt.legend(legend_labels, loc="lower left")

LIG2 = plt.figure(8)
plt.pie(results8, explode=explode8, colors=colors8, 
        autopct="%1.1f%%", shadow=True, startangle=90)
legend_labels = [r"Home Wins (37)", r"Away Wins (28)", r"Draws (25)"]
plt.axis("equal")
plt.title("Spanish La Liga home/away results without fans")
plt.legend(legend_labels, loc="lower left")

plt.savefig("LIG1.png")
plt.savefig("LIG2.png")
plt.show()

# %%
# total of all leagues before and after COVID break
results9_type = ["Home Wins", "Away Wins", "Draws"]
results9 = [458,335,245]
colors9 = ["palegreen","palegoldenrod","silver"]
explode9 = (0.1,0,0)

results10_type = ["Home Wins", "Away Wins", "Draws"]
results10 = [130,96,72]
colors10 = ["palegreen","palegoldenrod","silver"]
explode10 = (0.1,0,0)

# %%
ALL1 = plt.figure(9)
plt.pie(results9, explode=explode9, colors=colors9, 
        autopct="%1.1f%%", shadow=True, startangle=90)
legend_labels = [r"Home Wins (458)", r"Away Wins (335)", r"Draws (245)"]
plt.axis("equal")
plt.title("Results in all leagues with fans in attendance")
plt.legend(legend_labels, loc="lower left")

ALL2 = plt.figure(10)
plt.pie(results10, explode=explode10, colors=colors10, 
        autopct="%1.1f%%", shadow=True, startangle=90)
legend_labels = [r"Home Wins (130)", r"Away Wins (96)", r"Draws (72)"]
plt.axis("equal")
plt.title("Results in all leagues without fans")
plt.legend(legend_labels, loc="lower left")

plt.savefig("ALL1.png")
plt.savefig("ALL2.png")
plt.show()
